# %% [markdown]
# ## Connecting Spotipy

# %%
# imports
import pandas as pd
import numpy as np
import spotipy #pip install spotipy first
import os
from decouple import config
from spotipy.oauth2 import SpotifyClientCredentials # required to access user data
import spotipy.util as util

# %%
# import spotify credentials from .env
# https://able.bio/rhett/how-to-set-and-get-environment-variables-in-python--274rgt5
cid = config('CLIENT_ID')
secret = config('CLIENT_SECRET')
user = '1230756733' ## CHANGE THIS BEFORE PUSH

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
# sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# get auth token for request:
# dont forget to set uri in creation of dev app in spotify dev
def get_token(scope=None): #get token and set scope later if want
    redirect_uri = "http://localhost:4000"
    token = util.prompt_for_user_token(user, scope, cid, secret, redirect_uri)
    return token

# %%
token = get_token(scope='playlist-modify-private') # can make public later

# %%
sp = spotipy.Spotify(auth=token)

# %%
# create playlist: POST https://api.spotify.com/v1/users/{user_id}/playlists

# %%
# CREATES PLAYLIST ON HDR ACCOUNT
# sp.user_playlist_create(user, '102008', public=False)

# %%
## make playlistname dynamic
make_playlist = sp.user_playlist_create(user, '102008', public=False)
mp_id = make_playlist["id"]

# %%
tracky = "heat waves"
artist = "glass animals"

search_query = tracky + ' ' + artist
search_results = sp.search(q=search_query, limit=1)
# omg it returns a song

# %%
search_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=heat+waves+glass+animals&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#        'href': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#        'id': '4yvcSjfu4PC0CYQyLy4wSq',
#        'name': 'Glass Animals',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
# ...

# %%
urtry = [search_results["tracks"]["items"][0]["uri"][14:]]

# %%
##https://stackoverflow.com/questions/30372835/how-can-i-increase-the-expiry-time-of-spotify-token
# after 1h, refresh_token
# token prop: expires_in

# %% [markdown]
# ## Importing in CSVs

# %%
# read scraped csv to df
df = pd.read_csv('./data/102008sample.csv')
df
# Out:
#                     title                            artist
# 0              Girlfriend                 Bow Wow & Omarion
# 1             Walk It Out                     Unk & Outkast
# 2                 Cyclone                  BABY BASH/T-PAIN
# 3                     BED                        J. HOLIDAY
# 4             Temperature                         Sean Paul
# 5                  HATERZ                    B.O.B./WES FIF
# 6                  Shawty                      PLIES/T-PAIN
# 7    HATE THAT I LOVE YOU                     RIHANNA/NE-YO
# 8             Money Maker      Ludacris & Pharrell Williams
# 9                  NO ONE                       Alicia Keys
# 10              A Bay Bay                   HURRICANE CHRIS
# 11       Ghetto Superstar                        Pras & Mya
# 12              KISS KISS                CHRIS BROWN/T-PAIN
# 13            WHAT IS IT?           BABY BASH/SEAN KINGSTON
# 14         DUFFLE BAG BOY           PLAYAZ CIRCLE/LIL WAYNE
# ...

# %%
def make_playlist():
    make_playlist = sp.user_playlist_create(user, 'ultest', public=False)
    mp_id = make_playlist["id"]
    
    for i, j in df.iterrows():
        title_x = j.title
        artist_x = j.artist
        search_query = title_x + ' ' + artist_x
        search_results = sp.search(q=search_query, limit=1)
        uri = [search_results["tracks"]["items"][0]["uri"]]
        sp.playlist_add_items(playlist_id=mp_id, items=uri)
    return mp_id

# %%
make_playlist()
# Out:
# --------------------------------------------------
# IndexError       Traceback (most recent call last)
# <ipython-input-287-faf6350da35f> in <module>
# ----> 1 make_playlist()
#
# <ipython-input-286-860be0ff8a91> in make_playlist()
#       8         search_query = title_x + ' ' + artist_x
#       9         search_results = sp.search(q=search_query, limit=1)
# ---> 10         uri = [search_results["tracks"]["items"][0]["uri"]]
#      11         sp.playlist_add_items(playlist_id=mp_id, items=uri)
#      12     return mp_id
#
# IndexError: list index out of range
